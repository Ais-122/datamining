# %% [markdown]
# # Implementasi K-NN

# %%
import pandas as pd
#read in the data using pandas
df = pd.read_csv(‘data/diabetes_data.csv’)
#check data has been read in properly
df.head()
# Out:
#   File "<ipython-input-1-1cfd3253ca78>", line 3
#     df = pd.read_csv(‘data/diabetes_data.csv’)
#                          ^
# SyntaxError: invalid character in identifier
