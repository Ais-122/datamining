# %% [markdown]
# # Disimilarity (Tugas 1)

# %%
import pandas as pd
import numpy as np

# %%
dataset_url="https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/latest/owid-covid-latest.csv"
data=pd.read_csv(dataset_url, index_col=0)

# %%
data
# Out:
#          continent           location last_updated_date  total_cases  \
# iso_code
# AFG           Asia        Afghanistan        2022-09-11     195925.0
# OWID_AFR       NaN             Africa        2022-09-11   12337339.0
# ALB         Europe            Albania        2022-09-11     331036.0
# DZA         Africa            Algeria        2022-09-11     270539.0
# AND         Europe            Andorra        2022-09-11      46113.0
# ...            ...                ...               ...          ...
# WLF        Oceania  Wallis and Futuna        2022-09-11        761.0
# OWID_WRL       NaN              World        2022-09-11  608518726.0
# YEM           Asia              Yemen        2022-09-11      11932.0
# ZMB         Africa             Zambia        2022-09-11     333229.0
# ZWE         Africa           Zimbabwe        2022-09-11     256870.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# iso_code
# AFG           294.0             251.714        7787.0         0.0
# OWID_AFR      401.0            1182.571      256632.0         0.0
# ALB            88.0             120.429        3584.0         0.0
# DZA             7.0              13.714        6879.0         0.0
# AND             0.0              12.286         155.0         0.0
# ...             ...                 ...           ...         ...
# WLF             0.0               0.000           7.0         0.0
# OWID_WRL   311106.0          498143.857     6513932.0       701.0
# YEM             0.0               0.143        2155.0         0.0
# ZMB             9.0              22.143        4017.0         0.0
# ZWE             0.0              15.286        5596.0         0.0
#
#           new_deaths_smoothed  total_cases_per_million  ...  female_smokers  \
# iso_code                                                ...
# AFG                     0.714                 4885.976  ...             NaN
# OWID_AFR               10.143                 8860.521  ...             NaN
# ALB                     0.143               115961.341  ...           7.100
# DZA                     0.000                 6123.844  ...           0.700
# AND                     0.143               583457.752  ...          29.000
# ...                       ...                      ...  ...             ...
# WLF                     0.000                65451.105  ...             NaN
# OWID_WRL             1738.714                76937.162  ...           6.434
# YEM                     0.000                  361.777  ...           7.600
# ZMB                     0.000                17112.251  ...           3.100
# ZWE                     0.000                16060.876  ...           1.600
#
#           male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# iso_code
# AFG                NaN                  37.746                       0.500
# OWID_AFR           NaN                     NaN                         NaN
# ALB             51.200                     NaN                       2.890
# DZA             30.400                  83.741                       1.900
# AND             37.800                     NaN                         NaN
# ...                ...                     ...                         ...
# WLF                NaN                     NaN                         NaN
# OWID_WRL        34.635                  60.130                       2.705
# YEM             29.200                  49.542                       0.700
# ZMB             24.700                  13.938                       2.000
# ZWE             30.700                  36.791                       1.700
#
#           life_expectancy  human_development_index  \
# iso_code
# AFG                 64.83                    0.511
# OWID_AFR              NaN                      NaN
# ALB                 78.57                    0.795
# DZA                 76.88                    0.748
# AND                 83.73                    0.868
# ...                   ...                      ...
# WLF                 79.94                      NaN
# OWID_WRL            72.58                    0.737
# YEM                 66.12                    0.470
# ZMB                 63.89                    0.584
# ZWE                 61.49                    0.571
#
#           excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# iso_code
# AFG                                        NaN                          NaN
# OWID_AFR                                   NaN                          NaN
# ALB                                        NaN                          NaN
# DZA                                        NaN                          NaN
# AND                                        NaN                          NaN
# ...                                        ...                          ...
# WLF                                        NaN                          NaN
# OWID_WRL                                   NaN                          NaN
# YEM                                        NaN                          NaN
# ZMB                                        NaN                          NaN
# ZWE                                        NaN                          NaN
#
#           excess_mortality  excess_mortality_cumulative_per_million
# iso_code
# AFG                    NaN                                      NaN
# OWID_AFR               NaN                                      NaN
# ALB                    NaN                                      NaN
# DZA                    NaN                                      NaN
# AND                    NaN                                      NaN
# ...                    ...                                      ...
# WLF                    NaN                                      NaN
# OWID_WRL               NaN                                      NaN
# YEM                    NaN                                      NaN
# ZMB                    NaN                                      NaN
# ZWE                    NaN                                      NaN
#
# [231 rows x 66 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data[["continent","location","total_cases","total_deaths"]].head(4)
# Out:
#          continent     location  total_cases  total_deaths
# iso_code
# AFG           Asia  Afghanistan     195925.0        7787.0
# OWID_AFR       NaN       Africa   12337339.0      256632.0
# ALB         Europe      Albania     331036.0        3584.0
# DZA         Africa      Algeria     270539.0        6879.0

# %%
data[["continent","location"]].head(4)
# Out:
#          continent     location
# iso_code
# AFG           Asia  Afghanistan
# OWID_AFR       NaN       Africa
# ALB         Europe      Albania
# DZA         Africa      Algeria

# %%
def diss(x,y):
   p=2
   m=0
   for row in["continent","location"]:
      if data[row][x] == data[row][y]:
         m+=1
      return (p-m)/p

print(diss(1,1))
print(diss(1,2))
print(diss(1,3))
# Out:
# 1.0
# 1.0
# 1.0
